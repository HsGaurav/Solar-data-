# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[1,4,9,16])
plt.axis([0,5,0,18])
# Out:
# [0, 5, 0, 18]

# %%
import numpy as np
import matplotlib.pyplot as plt

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, 9*t, 'r--', t, t**2, 'bs', t, t**3, 'g^')

# %%
np.arange(0., 5., 0.2)
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4,
#        2.6, 2.8, 3. , 3.2, 3.4, 3.6, 3.8, 4. , 4.2, 4.4, 4.6, 4.8])

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

# plt.figure()
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')

# %%
# COMPARISION OF FIXED MOUNT WITH SINGLE AXIS TRACKER SYSTEM
import numpy as np
import matplotlib.pyplot as plt
v1 = np.arange(8.0, 19.0, 1.0)
v2 = np.array([8.4, 8.5,8.6,9.7, 9.9, 10.3, 10.5, 9.7, 8.6, 8.3, 8.1])
plt.plot(v1, v2, 'bo', v1, v2, 'k')
plt.axis([8, 18, 8, 10.9])
plt.xlabel('Time')
plt.ylabel('Voltage (v)')
# static panel voltage

# %%
# COMPARISION OF FIXED MOUNT WITH SINGLE AXIS TRACKER SYSTEM
import numpy as np
import matplotlib.pyplot as plt
i1 = np.arange(8.0, 19.0, 1.0)
i2 = np.array([0.60, 1.17, 1.25, 1.82, 2.22, 2.56, 2.97, 2.71, 2.50, 2.14, 1.43])
plt.plot(i1, i2, 'bo', i1, i2, 'k')
plt.axis([8, 18, 0, 3.1])
plt.xlabel('Time')
plt.ylabel('Current (mA)')
# Current in mA of static panel

# %%
# COMPARISION OF FIXED MOUNT WITH SINGLE AXIS TRACKER SYSTEM
import numpy as np
import matplotlib.pyplot as plt
w1 = np.arange(8.0, 19.0, 1.0)
w2 = np.array([5.04, 9.94, 10.75, 17.65, 21.97, 26.36, 31.18, 26.28, 21.50, 17.76, 11.58])
plt.plot(w1, w2, 'bo', w1, w2, 'k')
plt.axis([8, 18, 0, 35])
plt.xlabel('Time')
plt.ylabel('Power (mW)')
# Watt in mW of static panel

# %%
# COMPARISION OF FIXED MOUNT WITH SINGLE AXIS TRACKER SYSTEM
import numpy as np
import matplotlib.pyplot as plt
v1 = np.arange(8.0, 19.0, 1.0)
v2 = np.array([9.15, 9.45, 9.70, 9.85, 10.20, 10.80, 10.70, 10.25, 9.80, 9.25, 8.75])
plt.plot(v1, v2, 'bo', v1, v2, 'k')
plt.xlabel('Time')
plt.ylabel('Voltage (v)')
# plt.axis([8, 18, 0, 35])
# solar tracking single axis voltage

# %%
# COMPARISION OF FIXED MOUNT WITH SINGLE AXIS TRACKER SYSTEM
import numpy as np
import matplotlib.pyplot as plt
i1 = np.arange(8.0, 19.0, 1.0)
i2 = np.array([1.70, 1.78, 1.99, 2.38, 2.70, 3.20, 3.05, 2.93, 2.63, 2.43, 1.87])
plt.plot(i1, i2, 'bo', i1, i2, 'k')
plt.axis([8, 18, 1.6, 3.3])
plt.xlabel('Time')
plt.ylabel('Current (mA)')
# Current in mA of solar tracking single axis

# %%
# COMPARISION OF FIXED MOUNT WITH SINGLE AXIS TRACKER SYSTEM
import numpy as np
import matplotlib.pyplot as plt
w1 = np.arange(8.0, 19.0, 1.0)
w2 = np.array([15.60, 16.86, 19.30, 23.44, 27.54, 34.29, 32.68, 30.08, 25.77, 22.47, 16.40])
plt.plot(w1, w2, 'bo', w1, w2, 'k')
plt.xlabel('Time')
plt.ylabel('Power (mW)')
# plt.axis([8, 18, 0, 35])
# Watt in mW of solar tracking single axis

# %%
import matplotlib.pyplot as plt
import numpy as np
 
o = ['Static Panel', 'Solar Tracking (Single Axis)']
y_pos = np.arange(len(o))
avg_power = [18, 24]
 
plt.bar(y_pos, avg_power, align='center', width = 0.5, tick_label = o)
plt.ylabel('Power')
plt.title('Average Power Graph')
